# %% [markdown]
# # Seminar (Week 3)
#
# Dataset: https://disk.yandex.ru/d/B-bVBC3_1qQltw

# %%
import dataclasses
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from sklearn.decomposition import PCA
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as torch_data
import torchaudio
import tqdm.notebook as tqdm
import urllib

from IPython.display import clear_output

# %%
base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'
public_key = 'https://disk.yandex.ru/d/B-bVBC3_1qQltw'
final_url = base_url + urllib.parse.urlencode(dict(public_key=public_key))
response = requests.get(final_url)
download_url = response.json()['href']
# !mkdir -p data_sem
# !wget -O biometry_sem.tar.gz "{download_url}"
# !tar -xf biometry_sem.tar.gz -C data_sem
# Out:
# --2026-02-27 19:08:25--  https://downloader.disk.yandex.ru/disk/6becd525ab812a1371cbb0f17f51eaff2e579cbe5a415a1b1d918ad69c240661/69a207c8/gtj3WQiuHGabqHv6W0pVHGiPBEbqdNNVbyo0dVvDLDdrLIRyE43f_xtMZeGYtpSTCAoGQktSQmeooDnE3qr-Ng%3D%3D?uid=0&filename=biometry_small.tar.gz&disposition=attachment&hash=oYZlbrNPY%2Bg7thksSdqW/V4q%2BovTi6%2BkYy7dKjipwLYkRD0nE0OIZABtGgKbGFzQq/J6bpmRyOJonT3VoXnDag%3D%3D%3A&limit=0&content_type=application%2Fx-gzip&owner_uid=163052607&fsize=415942345&hid=e555bbb4aeabb8ac81024c715d3b676e&media_type=compressed&tknv=v3
# Resolving downloader.disk.yandex.ru (downloader.disk.yandex.ru)... 2a02:6b8::2:127, 77.88.21.127
# Connecting to downloader.disk.yandex.ru (downloader.disk.yandex.ru)|2a02:6b8::2:127|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s506klg.storage.yandex.net/rdisk/6becd525ab812a1371cbb0f17f51eaff2e579cbe5a415a1b1d918ad69c240661/69a207c8/gtj3WQiuHGabqHv6W0pVHGiPBEbqdNNVbyo0dVvDLDdrLIRyE43f_xtMZeGYtpSTCAoGQktSQmeooDnE3qr-Ng==?uid=0&filename=biometry_small.tar.gz&disposition=attachment&hash=oYZlbrNPY%2Bg7thksSdqW/V4q%2BovTi6%2BkYy7dKjipwLYkRD0nE0OIZABtGgKbGFzQq/J6bpmRyOJonT3VoXnDag%3D%3D%3A&limit=0&content_type=application%2Fx-gzip&owner_uid=163052607&fsize=415942345&hid=e555bbb4aeabb8ac81024c715d3b676e&media_type=compressed&tknv=v3&ts=64bd4a33b8200&s=ab8d36fd997fed8a038baf9399163ac1ac19adb586d0fd53b252a74828a590db&pb=U2FsdGVkX1_lwORucw71W1AIiCXGbZttCmBAf_3hWbv-OSJdxB6tAMRx3ovCB-AJHzndUM7ibg9P8vTtV4QMLeDjtfEop74Wt7iYEZbAS_Y [following]
# --2026-02-27 19:08:26--  https://s506klg.storage.yandex.net/rdisk/6becd525ab812a1371cbb0f17f51eaff2e579cbe5a415a1b1d918ad69c240661/69a207c8/gtj3WQiuHGabqHv6W0pVHGiPBEbqdNNVbyo0dVvDLDdrLIRyE43f_xtMZeGYtpSTCAoGQktSQmeooDnE3qr-Ng==?uid=0&filename=biometry_small.tar.gz&disposition=attachment&hash=oYZlbrNPY%2Bg7thksSdqW/V4q%2BovTi6%2BkYy7dKjipwLYkRD0nE0OIZABtGgKbGFzQq/J6bpmRyOJonT3VoXnDag%3D%3D%3A&limit=0&content_type=application%2Fx-gzip&owner_uid=163052607&fsize=415942345&hid=e555bbb4aeabb8ac81024c715d3b676e&media_type=compressed&tknv=v3&ts=64bd4a33b8200&s=ab8d36fd997fed8a038baf9399163ac1ac19adb586d0fd53b252a74828a590db&pb=U2FsdGVkX1_lwORucw71W1AIiCXGbZttCmBAf_3hWbv-OSJdxB6tAMRx3ovCB-AJHzndUM7ibg9P8vTtV4QMLeDjtfEop74Wt7iYEZbAS_Y
# Resolving s506klg.storage.yandex.net (s506klg.storage.yandex.net)... 2a02:6b8:c41:812:0:41af:10be:376e, 77.88.0.250
# Connecting to s506klg.storage.yandex.net (s506klg.storage.yandex.net)|2a02:6b8:c41:812:0:41af:10be:376e|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 415942345 (397M) [application/x-gzip]
# Saving to: ‘biometry_sem.tar.gz’
#
# biometry_sem.tar.gz 100%[===================>] 396.67M  5.97MB/s    in 4m 5s
#
# 2026-02-27 19:12:31 (1.62 MB/s) - ‘biometry_sem.tar.gz’ saved [415942345/415942345]

# %%
DATA = 'data_sem'
DEVICE = 'mps'  # 'cuda' or 'cpu'
TARGETS = os.path.join(DATA, 'targets.csv')
IN_DIM = 40

# %%
class Dataset(torch_data.Dataset):
    @dataclasses.dataclass
    class Item:
        feats: torch.tensor
        speaker: int
        age: int
        gender: int
        room: int

    def __init__(self, transform: nn.Module, speakers=(1, 2, 3), genders=(0, 1)):
        targets = pd.read_csv(TARGETS)
        self._speakers = {}
        self._data = []
        for _, row in tqdm.tqdm(targets.iterrows(), total=len(targets)):
            if int(row.speaker.split('_')[0]) not in speakers:
                continue
            if row.gender not in genders:
                continue
            path = os.path.join(DATA, row.audio)
            wav = torchaudio.load(path)[0]
            feats = transform(wav)[0]
            if row.speaker not in self._speakers:
                self._speakers[row.speaker] = len(self._speakers)
            speaker_id = self._speakers[row.speaker]
            self._data.append(self.Item(feats, speaker_id, row.age, row.gender, int(row.speaker.split('_')[0])))

    def __getitem__(self, idx):
        return self._data[idx]

    def __len__(self):
        return len(self._data)

    def speakers(self):
        return len(self._speakers)

def collate_fn(batch: list[Dataset.Item]):
    feats = [item.feats for item in batch]
    max_len = max([feat.shape[1] for feat in feats])
    X = torch.zeros((len(batch), IN_DIM, max_len))
    for idx, feat in enumerate(feats):
        X[idx,:,:feat.shape[1]] = feat
    Y = torch.tensor([item.speaker for item in batch], dtype=torch.long, device=DEVICE)
    age = [item.age for item in batch]
    gender = [item.gender for item in batch]
    room = [item.room for item in batch]
    return X.to(DEVICE), Y, age, gender, room

# %%
dataset = Dataset(torchaudio.transforms.MFCC(n_mfcc=40))
# Out:
# /Users/liablefish/github/speech_course/.venv/lib/python3.10/site-packages/torchaudio/functional/functional.py:581: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   warnings.warn(
#   0%|          | 0/16260 [00:00<?, ?it/s]

# %% [markdown]
# ### Train model
#
# Train simple model for biometrics classification:

# %%
class AttentiveStatsPooling(nn.Module):
    def __init__(self, hidden):
        super().__init__()
        self._weight = nn.Sequential(
            nn.Conv1d(hidden, hidden, kernel_size=1),
            nn.GELU(),
            nn.Conv1d(hidden, hidden, kernel_size=1),
            nn.Softmax(dim=2)
        )

    def forward(self, X):
        weight = self._weight(X)
        return torch.sum(X * weight, dim=2).unsqueeze(dim=2)

class Model(nn.Module):
    def __init__(self, in_dim, out_dim, hidden=32, kernel=11):
        super().__init__()
        self._body = nn.Sequential(
            nn.Conv1d(in_dim, hidden, kernel_size=kernel),
            nn.BatchNorm1d(hidden),
            nn.GELU(),
            nn.MaxPool1d(2),
            nn.Conv1d(hidden, hidden, kernel_size=kernel),
            nn.BatchNorm1d(hidden),
            nn.GELU(),
            nn.MaxPool1d(2),
            nn.Conv1d(hidden, hidden, kernel_size=kernel),
            nn.BatchNorm1d(hidden),
            AttentiveStatsPooling(hidden),
        )
        self._head = nn.Sequential(
            nn.Linear(hidden, hidden),
            nn.GELU(),
            nn.Linear(hidden, out_dim),
        )

    def forward(self, X):
        # X: [batch, channels, time]
        emb = self._body(X).squeeze(2)  # <YOUR CODE IS HERE>
        return self._head(emb), emb

# %%
def train(model: nn.Module, epochs=10, batch_size=256):
    opt = optim.Adam(model.parameters())
    data = torch_data.DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
    losses = []
    accs = []
    for _ in range(epochs):
        loss_sum = 0
        acc_sum = 0
        batches = 0
        for X, Y, _, _, _ in tqdm.tqdm(data):
            logits, _ = model.forward(X)
            logits = logits.squeeze()
            loss = F.cross_entropy(logits, Y)
            with torch.no_grad():
                acc = torch.sum(torch.argmax(logits, dim=-1) == Y) / X.shape[0]
            opt.zero_grad()
            loss.backward()
            opt.step()
            loss_sum += loss.item()
            acc_sum += acc.item()
            batches += 1
        losses.append(loss_sum / batches)
        accs.append(acc_sum / batches)
        clear_output()
        fig, axis = plt.subplots(1, 2, figsize=(15, 7))
        axis[0].plot(losses)
        axis[1].plot(accs)
        plt.show()
        print('Train loss:', losses[-1], 'Accuracy:', accs[-1])

# %%
model = Model(IN_DIM, dataset.speakers()).to(DEVICE)
train(model, epochs=50)
# Out:
# Train loss: 1.3207578491419554 Accuracy: 0.6270197089761496

# %% [markdown]
# ### Prepare embeddings
#
# Prepare embeddings of trained model, project to lower dimensional space.

# %%
embeddings = []
ages = []
genders = []
rooms = []
data = torch_data.DataLoader(dataset, batch_size=256, collate_fn=collate_fn)
model.eval()
with torch.no_grad():
    for X, _, age, gender, room in tqdm.tqdm(data):
        _, emb = model.forward(X)
        embeddings.extend(emb.squeeze().cpu().data.numpy())
        ages.extend(age)
        genders.extend(gender)
        rooms.extend(room)
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]

# %%
# <YOUR CODE IS HERE>
pca = PCA(n_components=2)
pca.fit(embeddings)
emb2dim = pca.transform(embeddings)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.16932824, 0.15336358])

# %% [markdown]
# ### Plot different classes
#
# Plot embeddings for different classes by age, gender and room conditions

# %%
# gender
for gen in [0, 1]:
    cur_emb = [emb for emb, gender in zip(emb2dim, genders) if gender == gen]
    print(np.mean(cur_emb, axis=0))
    x_limits = np.quantile([x for x, _ in cur_emb], [0.01, 0.99])
    y_limits = np.quantile([y for _, y in cur_emb], [0.01, 0.99])
    cur_emb = np.array(
        [(x, y) for x, y in cur_emb if x_limits[0] <= x <= x_limits[1] and y_limits[0] <= y <= y_limits[1]]
    )
    indexes = np.random.choice(np.arange(len(cur_emb)), size=500, replace=False)
    cur_emb = cur_emb[indexes]
    plt.plot([x for x, _ in cur_emb], [y for _, y in cur_emb], '.', label=gen)
plt.legend()
plt.show()
# Out:
# [-2.84164483  4.66354365]
# [ 1.80302193 -2.95901563]
